# %%
from GeneralPack.AOStar import program

# %%
def aoStar(obj, v, backTracking):
        print("HEURISTIC VALUES :", obj.H)
        print("SOLUTION GRAPH :", obj.solutionGraph)
        print("PROCESSING NODE :", v)
        print("-----------------------------------------------------------------------------------------")
        
        if obj.getStatus(v) >= 0: 
            minimumCost, childNodeList = obj.computeMinimumCostChildNodes(v)
            obj.setHeuristicNodeValue(v, minimumCost)
            obj.setStatus(v,len(childNodeList))
            solved=True
            for childNode in childNodeList:
                obj.parent[childNode]=v
                if obj.getStatus(childNode)!=-1:
                    solved=solved & False
            if solved==True:
                obj.setStatus(v,-1)
                obj.solutionGraph[v]=childNodeList 
            if v!=obj.start: 
                aoStar(obj,obj.parent[v], True)
            if backTracking==False:
                for childNode in childNodeList:
                    obj.setStatus(childNode,0)
                    aoStar(obj,childNode, False)

# %%
h1 = {'A': 1, 'B': 6, 'C': 2, 'D': 12, 'E': 2, 'F': 1, 'G': 5, 'H': 7, 'I': 7, 'J':1, 'T': 3}
graph1 = {
    'A': [[('B', 1), ('C', 1)], [('D', 1)]],
    'B': [[('G', 1)], [('H', 1)]],
    'C': [[('J', 1)]],
    'D': [[('E', 1), ('F', 1)]],
    'G': [[('I', 1)]]
}
G1= program(graph1, h1, 'A')
aoStar(G1,'A',False)
print(G1.solutionGraph)
# Out:
# HEURISTIC VALUES : {'A': 1, 'B': 6, 'C': 2, 'D': 12, 'E': 2, 'F': 1, 'G': 5, 'H': 7, 'I': 7, 'J': 1, 'T': 3}
# SOLUTION GRAPH : {}
# PROCESSING NODE : A
# -----------------------------------------------------------------------------------------
# HEURISTIC VALUES : {'A': 10, 'B': 6, 'C': 2, 'D': 12, 'E': 2, 'F': 1, 'G': 5, 'H': 7, 'I': 7, 'J': 1, 'T': 3}
# SOLUTION GRAPH : {}
# PROCESSING NODE : B
# -----------------------------------------------------------------------------------------
# HEURISTIC VALUES : {'A': 10, 'B': 6, 'C': 2, 'D': 12, 'E': 2, 'F': 1, 'G': 5, 'H': 7, 'I': 7, 'J': 1, 'T': 3}
# SOLUTION GRAPH : {}
# PROCESSING NODE : A
# -----------------------------------------------------------------------------------------
# HEURISTIC VALUES : {'A': 10, 'B': 6, 'C': 2, 'D': 12, 'E': 2, 'F': 1, 'G': 5, 'H': 7, 'I': 7, 'J': 1, 'T': 3}
# SOLUTION GRAPH : {}
# PROCESSING NODE : G
# -----------------------------------------------------------------------------------------
# ...

# %%
def AOStar(start, goal, h_func, g_func, r_func):
    # Initialize the open and closed sets
    open_set = {start}
    closed_set = set()

    # Initialize the g-value and h-value for the start node
    g_val = {start: 0}
    h_val = {start: h_func(start)}

    # Initialize the parent and cost-to-come functions
    parent = {start: start}
    cost = {start: h_val[start]}

    # Initialize the search depth and the maximum search depth
    depth = 0
    max_depth = float('inf')

    # Initialize the current best cost-to-go and the current cost-to-come
    cbctg = float('inf')
    cctc = float('inf')

    # Main loop
    while open_set:
        # Check if the search depth has reached the maximum depth
        if depth > max_depth:
            break

        # Select the node with the lowest cost-to-come value
        curr = min(open_set, key=lambda x: cost[x])

        # Check if the current node is the goal
        if curr == goal:
            # Return the path to the goal
            path = []
            while curr != start:
                path.append(curr)
                curr = parent[curr]
            path.append(start)
            return path[::-1]

        # Remove the current node from the open set and add it to the closed set
        open_set.remove(curr)
        closed_set.add(curr)

        # Increment the search depth
        depth += 1

        # Get the neighbors of the current node
        neighbors = get_neighbors(curr)

        # Iterate through the neighbors
        for neighbor in neighbors:
            # Calculate the cost-to-come and cost-to-go values for the neighbor
            ctc = g_val[curr] + g_func(curr, neighbor)
            ctg = h_func(neighbor)

            # Check if the neighbor is in the closed set
            if neighbor in closed_set:
                # Check if the current cost-to-come is lower than the previous cost-to-come
                if ctc < cost[neighbor]:
                    # Update the cost-to-come, cost-to-go, and parent functions
                    cost[neighbor] = ctc
                    g_val[neighbor] = ctc
                    h_val[neighbor] = ctg
                    parent[neighbor] = curr
            # Check if the neighbor is not in the open set
            elif neighbor not in open_set:
                # Add the neighbor to the open set
                open_set.add(neighbor)

                # Update the cost-to-come, cost-to-go, and parent functions
                cost[neighbor] = ctc


                # yes y Yes
